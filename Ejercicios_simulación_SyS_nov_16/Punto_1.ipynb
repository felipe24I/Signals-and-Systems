# %% [markdown]
# <a href="https://colab.research.google.com/github/felipe24I/Entregas/blob/main/Ejercicios_simulaci%C3%B3n_SyS_nov_16/Punto_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ejercicio**

# %% [markdown]
# 1. A partir del modelado y desarrollos del cuaderno https://github.com/amalvarezme/SenalesSistemas/blob/master/4_Transformada_Laplace/7_An%C3%A1lisis%20de%20redes.ipynb , encuentre la función de transferencia en lazo abierto para un circuito RLC serie (fuente tensión de entrada, salida de tensión en capacitor), y un circuito RLC paralelo (fuente corriente de entrada, salida de corriente en inductor), incluyendo condiciones iniciales distintas de cero.

# %% [markdown]
# #**Solución**

# %% [markdown]
# *   Circuito RLC serie

# %% [markdown]
# ![WhatsApp Image 2023-11-21 at 6.04.04 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-21 at 6.04.04 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# *   Circuito RLC paralelo

# %% [markdown]
# ![WhatsApp Image 2023-11-21 at 6.04.05 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-21 at 6.04.05 PM (1).jpeg](data:image/jpeg;base64,...)
