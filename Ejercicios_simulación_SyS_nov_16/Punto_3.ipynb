# %% [markdown]
# <a href="https://colab.research.google.com/github/felipe24I/Entregas/blob/main/Ejercicios_simulaci%C3%B3n_SyS_nov_16/Punto_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ejercicio**

# %% [markdown]
# 3. Para los sistemas estudiados en los puntos 1 y 2, determine la forma canónica de segundo orden y escriba el factor de amortiguamiento, la frecuencia natural amortiguada, la frecuencia natural no amortiguada, el tiempo de máximo sobre impulso, y el tiempo de establecimiento, en función de los parámetros del sistema (RLC y k m c). Ver  https://github.com/amalvarezme/SenalesSistemas/blob/master/4_Transformada_Laplace/9_Pendulo_Elastico.ipynb)

# %% [markdown]
# ![WhatsApp Image 2023-11-22 at 1.18.25 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-22 at 1.18.25 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-22 at 1.18.26 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-22 at 1.18.26 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-22 at 1.18.26 PM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-22 at 1.18.26 PM (3).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-22 at 1.18.27 PM.jpeg](data:image/jpeg;base64,...)
