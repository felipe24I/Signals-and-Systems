# %% [markdown]
# <a href="https://colab.research.google.com/github/felipe24I/Entregas/blob/main/hallar_k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sym
t= sym.symbols("t",real=True)
delta=sym.DiracDelta(2*t-5*sym.pi)
delta
x=(t**4)*sym.exp(-sym.cos(t))*sym.cos(-2*t)
sym.integrate(x*delta,(t,-sym.oo,sym.oo))
# Out:
# -625*pi**4/32

# %%
from sympy.functions.special.delta_functions import DiracDelta
import sympy as sym
t,n,to,k,m,A=sym.symbols("t n to k m A",real=True)
step_1=sym.Heaviside(t-to)
step_2=sym.Heaviside(t-n*to)
delta=DiracDelta(t-m*to)
A=sym.integrate(step_1-step_2-(3*k)*delta,(t,-sym.oo,sym.oo))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-6f52dcd3a1a3> in <cell line: 21>()
#      19
#      20 # Resolvemos la ecuación para k
# ---> 21 solucion_k = sym.solve(sym.Eq(A, integral_A), k)
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1143             solution = _solve_undetermined(f[0], symbols, flags)
#    1144         if not solution:
# -> 1145             solution = _solve(f[0], *symbols, **flags)
#    1146     else:
#    1147         linear, solution = _solve_system(f, symbols, **flags)
#
# /usr/local/lib/python3.10/dist-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1432             # no need to check but simplify if desired
#    1433             if flags.get('simplify', True):
# -> 1434                 sol = simplify(sol)
#    1435             return [{f_num: sol}]
# ...
